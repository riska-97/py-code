# %% [markdown]
# <a href="https://colab.research.google.com/github/riska-97/py-code/blob/main/Code_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture 3 (Code Challenge)

# %% [markdown]
# Click [here](https://docs.google.com/spreadsheets/d/1wArCQ8-e-crtb1TK9Fek5ZHh0rJpITFgTawF5ixrfU8/edit#gid=0) to see spreadsheet.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = 'https://docs.google.com/spreadsheets/d/1wArCQ8-e-crtb1TK9Fek5ZHh0rJpITFgTawF5ixrfU8/edit#gid=0'
url_use = url.replace('edit#','export?format=csv&')
df1 = pd.read_csv(url_use)
df1
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0          31.0                None      Front  ...        5.0   177.0
# 1          25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2          26.0         Driver only      Front  ...        5.0   180.0
# 3          26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4          30.0                 NaN       Rear  ...        4.0   186.0
# ..          ...                 ...        ...  ...        ...     ...
# 88         21.0                None      Front  ...        7.0   187.0
# 89         30.0                None      Front  ...        5.0   180.0
# 90         25.0                None      Front  ...        4.0   159.0
# 91         28.0         Driver only       Rear  ...        5.0   190.0
# 92         28.0  Driver & Passenger      Front  ...        5.0   184.0
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# 0       102.0   68.0         37.0           26.5           NaN  2705.0
# 1       115.0   71.0         38.0           30.0          15.0  3560.0
# 2       102.0   67.0         37.0           28.0          14.0  3375.0
# 3       106.0    NaN         37.0           31.0          17.0  3405.0
# 4       109.0   69.0         39.0           27.0          13.0  3640.0
# ..        ...    ...          ...            ...           ...     ...
# 88      115.0   72.0         38.0           34.0           NaN  3960.0
# 89      103.0   67.0         35.0           31.5          14.0  2985.0
# 90       97.0   66.0         36.0           26.0          15.0  2810.0
# 91      104.0   67.0         37.0           29.5          14.0  2985.0
# 92      105.0   69.0         38.0           30.0          15.0  3245.0
#
#      Origin                Make
# 0   non-USA       Acura Integra
# 1   non-USA        Acura Legend
# 2   non-USA             Audi 90
# 3   non-USA            Audi 100
# 4   non-USA            BMW 535i
# ..      ...                 ...
# 88      NaN  Volkswagen Eurovan
# 89  non-USA   Volkswagen Passat
# 90  non-USA  Volkswagen Corrado
# 91  non-USA           Volvo 240
# 92  non-USA           Volvo 850
#
# [93 rows x 27 columns]

# %%
df1.isna().sum()
# Out:
# Manufacturer           4
# Model                  1
# Type                   3
# Min.Price              7
# Price                  2
# Max.Price              5
# MPG.city               9
# MPG.highway            2
# AirBags                6
# DriveTrain             7
# Cylinders              5
# EngineSize             2
# Horsepower             7
# RPM                    3
# Rev.per.mile           6
# Man.trans.avail        5
# Fuel.tank.capacity     8
# Passengers             2
# Length                 4
# Wheelbase              1
# Width                  6
# Turn.circle            5
# Rear.seat.room         4
# Luggage.room          19
# Weight                 7
# Origin                 5
# Make                   3
# dtype: int64

# %% [markdown]
# Dari hasil code diatas, terlihat bahwa banyak sekali kolom yang null
#
# Lalu, akan di lihat berapa banyak row yang memiliki nilai null dan row yg tidak ada nilai null

# %%
df1[df1.isnull().any(axis=1)]
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# 5         Buick  Century  Midsize       14.2   15.7       17.3      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 85       Toyota    Camry  Midsize       15.2    NaN       21.2      22.0
# 86       Toyota   Previa      Van        NaN   22.7       26.6      18.0
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0          31.0                None      Front  ...        5.0   177.0
# 1          25.0  Driver & Passenger      Front  ...        5.0   195.0
# 3          26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4          30.0                 NaN       Rear  ...        4.0   186.0
# 5          31.0         Driver only        NaN  ...        6.0   189.0
# ..          ...                 ...        ...  ...        ...     ...
# 85         29.0         Driver only        NaN  ...        5.0   188.0
# 86         22.0         Driver only        4WD  ...        7.0   187.0
# 88         21.0                None      Front  ...        7.0   187.0
# 91         28.0         Driver only       Rear  ...        5.0   190.0
# 92         28.0  Driver & Passenger      Front  ...        5.0   184.0
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# 0       102.0   68.0         37.0           26.5           NaN  2705.0
# 1       115.0   71.0         38.0           30.0          15.0  3560.0
# 3       106.0    NaN         37.0           31.0          17.0  3405.0
# 4       109.0   69.0         39.0           27.0          13.0  3640.0
# 5       105.0   69.0         41.0           28.0          16.0     NaN
# ..        ...    ...          ...            ...           ...     ...
# 85      103.0   70.0         38.0           28.5          15.0  3030.0
# 86      113.0   71.0         41.0           35.0           NaN  3785.0
# 88      115.0   72.0         38.0           34.0           NaN  3960.0
# 91      104.0   67.0         37.0           29.5          14.0  2985.0
# 92      105.0   69.0         38.0           30.0          15.0  3245.0
#
#      Origin                Make
# 0   non-USA       Acura Integra
# 1   non-USA        Acura Legend
# 3   non-USA            Audi 100
# 4   non-USA            BMW 535i
# 5       USA       Buick Century
# ..      ...                 ...
# 85  non-USA        Toyota Camry
# 86  non-USA       Toyota Previa
# 88      NaN  Volkswagen Eurovan
# 91  non-USA           Volvo 240
# 92  non-USA           Volvo 850
#
# [73 rows x 27 columns]

# %%
df1[~df1.isnull().any(axis=1)]
# Out:
#    Manufacturer       Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 2          Audi          90  Compact       25.9   29.1       32.3      20.0
# 7         Buick  Roadmaster    Large       22.6   23.7       24.9      16.0
# 17    Chevrolet     Caprice    Large       18.0   18.8       19.6      17.0
# 20     Chrysler     LeBaron  Compact       14.5   15.8       17.1      23.0
# 21     Chrysler    Imperial    Large       29.5   29.5       29.5      20.0
# 28        Eagle      Summit    Small        7.9   12.2       16.5      29.0
# 43      Hyundai       Excel    Small        6.8    8.0        9.2      29.0
# 52        Mazda         323    Small        7.4    8.3        9.1      29.0
# 53        Mazda     Protege    Small       10.9   11.6       12.3      28.0
# 54        Mazda         626  Compact       14.3   16.5       18.7      26.0
# 60      Mercury      Cougar  Midsize       14.9   14.9       14.9      19.0
# 64       Nissan      Altima  Compact       13.0   15.7       18.3      24.0
# 67   Oldsmobile     Achieva  Compact       13.0   13.5       14.0      24.0
# 75      Pontiac  Grand_Prix  Midsize       15.4   18.5       21.6      19.0
# 76      Pontiac  Bonneville    Large       19.4   24.4       29.4      19.0
# 79       Subaru       Justy    Small        7.3    8.4        9.5      33.0
# 80       Subaru      Loyale    Small       10.5   10.9       11.3      25.0
# 87   Volkswagen         Fox    Small        8.7    9.1        9.5      25.0
# 89   Volkswagen      Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen     Corrado   Sporty       22.9   23.3       23.7      18.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 2          26.0         Driver only      Front  ...        5.0   180.0
# 7          25.0         Driver only       Rear  ...        6.0   216.0
# 17         26.0         Driver only       Rear  ...        6.0   214.0
# 20         28.0  Driver & Passenger      Front  ...        6.0   183.0
# 21         26.0         Driver only      Front  ...        6.0   203.0
# 28         33.0                None      Front  ...        5.0   174.0
# 43         33.0                None      Front  ...        5.0   168.0
# 52         37.0                None      Front  ...        4.0   164.0
# 53         36.0                None      Front  ...        5.0   172.0
# 54         34.0         Driver only      Front  ...        5.0   184.0
# 60         26.0                None       Rear  ...        5.0   199.0
# 64         30.0         Driver only      Front  ...        5.0   181.0
# 67         31.0                None      Front  ...        5.0   188.0
# 75         27.0                None      Front  ...        5.0   195.0
# 76         28.0  Driver & Passenger      Front  ...        6.0   177.0
# 79         37.0                None        4WD  ...        4.0   146.0
# 80         30.0                None        4WD  ...        5.0   175.0
# 87         33.0                None      Front  ...        4.0   163.0
# 89         30.0                None      Front  ...        5.0   180.0
# 90         25.0                None      Front  ...        4.0   159.0
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# 2       102.0   67.0         37.0           28.0          14.0  3375.0
# 7       116.0   78.0         45.0           30.5          21.0  4105.0
# 17      116.0   77.0         42.0           29.5          20.0  3910.0
# 20      104.0   68.0         41.0           30.5          14.0  3085.0
# 21      110.0   69.0         44.0           36.0          17.0  3570.0
# 28       98.0   66.0         36.0           26.5          11.0  2295.0
# 43       94.0   63.0         35.0           26.0          11.0  2345.0
# 52       97.0   66.0         34.0           27.0          16.0  2325.0
# 53       98.0   66.0         36.0           26.5          13.0  2440.0
# 54      103.0   69.0         40.0           29.5          14.0  2970.0
# 60      113.0   73.0         38.0           28.0          15.0  3610.0
# 64      103.0   67.0         40.0           28.5          14.0  3050.0
# 67      103.0   67.0         39.0           28.0          14.0  2910.0
# 75      108.0   72.0         41.0           28.5          16.0  3450.0
# 76      111.0   74.0         43.0           30.5          18.0  3495.0
# 79       90.0   60.0         32.0           23.5          10.0  2045.0
# 80       97.0   65.0         35.0           27.5          15.0  2490.0
# 87       93.0   63.0         34.0           26.0          10.0  2240.0
# 89      103.0   67.0         35.0           31.5          14.0  2985.0
# 90       97.0   66.0         36.0           26.0          15.0  2810.0
#
#      Origin                Make
# 2   non-USA             Audi 90
# 7       USA    Buick Roadmaster
# 17      USA   Chevrolet Caprice
# 20      USA    Chrysler LeBaron
# 21      USA   Chrysler Imperial
# 28      USA        Eagle Summit
# 43  non-USA       Hyundai Excel
# 52  non-USA           Mazda 323
# 53  non-USA       Mazda Protege
# 54  non-USA           Mazda 626
# 60      USA      Mercury Cougar
# 64  non-USA       Nissan Altima
# 67      USA  Oldsmobile Achieva
# 75      USA  Pontiac Grand_Prix
# 76      USA  Pontiac Bonneville
# 79  non-USA        Subaru Justy
# 80  non-USA       Subaru Loyale
# 87  non-USA      Volkswagen Fox
# 89  non-USA   Volkswagen Passat
# 90  non-USA  Volkswagen Corrado
#
# [20 rows x 27 columns]

# %% [markdown]
# Dari hasil di atas, terlihat bahwa dari 93 rows yang dimiliki : 73 rows memiliki nilai null dan 20 rows yg tidak ada nilai null.
#
# Oleh karena itu, perlu dipilih kolom yang ingin di gunakan untuk analisa agar tidak terlalu banyak drop data.
#
# Misal, ingin dianalisa mengenai perbandingan Harga Mobil yang dibuat di US dan non-US.
#
# Kolom yang dibutuhkan adalah Manufacturer, Model Mobil, Price dan Origin. Maka akan dibuat dataframe baru yang hanya memuat ke-4 kolom tsb.

# %%
df2 = df1[['Manufacturer','Model','Price','Origin']]
df2
# Out:
#    Manufacturer    Model  Price   Origin
# 0         Acura  Integra   15.9  non-USA
# 1           NaN   Legend   33.9  non-USA
# 2          Audi       90   29.1  non-USA
# 3          Audi      100   37.7  non-USA
# 4           BMW     535i   30.0  non-USA
# ..          ...      ...    ...      ...
# 88   Volkswagen  Eurovan   19.7      NaN
# 89   Volkswagen   Passat   20.0  non-USA
# 90   Volkswagen  Corrado   23.3  non-USA
# 91        Volvo      240   22.7  non-USA
# 92          NaN      850   26.7  non-USA
#
# [93 rows x 4 columns]

# %%
df2[df2.isnull().any(axis=1)]
# Out:
#      Manufacturer     Model  Price   Origin
# 1             NaN    Legend   33.9  non-USA
# 18      Chevrolet  Corvette   38.0      NaN
# 19            NaN  Concorde   18.4      USA
# 46        Hyundai    Sonata   13.9      NaN
# 49            NaN     SC300   35.2  non-USA
# 57  Mercedes-Benz      190E   31.9      NaN
# 59        Mercury       NaN   14.1      USA
# 71       Plymouth     Laser   14.4      NaN
# 78         Saturn        SL    NaN      USA
# 85         Toyota     Camry    NaN  non-USA
# 88     Volkswagen   Eurovan   19.7      NaN
# 92            NaN       850   26.7  non-USA

# %% [markdown]
# Dari hasil di atas, terlihat bahwa >10% rows data masih memiliki nilai null.
#
# Selanjutnya akan di lakukan modifikasi data yaitu menyatukan kolom manufacturer dan Model menjadi 1 kolom baru dan mengisi nilai harga dengan asumsi harga = rata-rata dari Max. Price dan Min. Price.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        89 non-null     object
#  1   Model               92 non-null     object
#  2   Type                90 non-null     object
#  3   Min.Price           86 non-null     float64
#  4   Price               91 non-null     float64
#  5   Max.Price           88 non-null     float64
#  6   MPG.city            84 non-null     float64
#  7   MPG.highway         91 non-null     float64
#  8   AirBags             87 non-null     object
#  9   DriveTrain          86 non-null     object
#  10  Cylinders           88 non-null     object
#  11  EngineSize          91 non-null     float64
#  12  Horsepower          86 non-null     float64
#  13  RPM                 90 non-null     float64
#  14  Rev.per.mile        87 non-null     float64
#  15  Man.trans.avail     88 non-null     object
#  16  Fuel.tank.capacity  85 non-null     float64
#  17  Passengers          91 non-null     float64
#  18  Length              89 non-null     float64
#  19  Wheelbase           92 non-null     float64
#  20  Width               87 non-null     float64
#  21  Turn.circle         88 non-null     float64
#  22  Rear.seat.room      89 non-null     float64
#  23  Luggage.room        74 non-null     float64
#  24  Weight              86 non-null     float64
#  25  Origin              88 non-null     object
#  26  Make                90 non-null     object
# dtypes: float64(18), object(9)
# memory usage: 19.7+ KB

# %%
df1_modif = df1.copy()
df1_modif['Manufacturer'] = df1_modif['Manufacturer'].replace(np.nan,'',regex=True)
df1_modif['Model'] = df1_modif['Model'].replace(np.nan,'',regex=True)
df1_modif['Car_Name'] = df1_modif['Manufacturer'] + ' ' + df1_modif['Model']
df1_modif['Avg_Price'] = df1_modif['Min.Price'] + df1_modif['Max.Price'] / 2
df1_modif['Price'].fillna(df1_modif['Avg_Price'],axis=0,inplace=True)
df1_modif
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1                 Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92                   850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Wheelbase  Width  \
# 0          31.0                None      Front  ...     102.0   68.0
# 1          25.0  Driver & Passenger      Front  ...     115.0   71.0
# 2          26.0         Driver only      Front  ...     102.0   67.0
# 3          26.0  Driver & Passenger        NaN  ...     106.0    NaN
# 4          30.0                 NaN       Rear  ...     109.0   69.0
# ..          ...                 ...        ...  ...       ...    ...
# 88         21.0                None      Front  ...     115.0   72.0
# 89         30.0                None      Front  ...     103.0   67.0
# 90         25.0                None      Front  ...      97.0   66.0
# 91         28.0         Driver only       Rear  ...     104.0   67.0
# 92         28.0  Driver & Passenger      Front  ...     105.0   69.0
#
#     Turn.circle  Rear.seat.room  Luggage.room  Weight   Origin  \
# 0          37.0            26.5           NaN  2705.0  non-USA
# 1          38.0            30.0          15.0  3560.0  non-USA
# 2          37.0            28.0          14.0  3375.0  non-USA
# 3          37.0            31.0          17.0  3405.0  non-USA
# 4          39.0            27.0          13.0  3640.0  non-USA
# ..          ...             ...           ...     ...      ...
# 88         38.0            34.0           NaN  3960.0      NaN
# 89         35.0            31.5          14.0  2985.0  non-USA
# 90         36.0            26.0          15.0  2810.0  non-USA
# 91         37.0            29.5          14.0  2985.0  non-USA
# 92         38.0            30.0          15.0  3245.0  non-USA
#
#                   Make            Car_Name  Avg_Price
# 0        Acura Integra       Acura Integra      22.30
# 1         Acura Legend              Legend      48.55
# 2              Audi 90             Audi 90      42.05
# 3             Audi 100            Audi 100        NaN
# 4             BMW 535i            BMW 535i        NaN
# ..                 ...                 ...        ...
# 88  Volkswagen Eurovan  Volkswagen Eurovan      27.95
# 89   Volkswagen Passat   Volkswagen Passat      28.80
# 90  Volkswagen Corrado  Volkswagen Corrado      34.75
# 91           Volvo 240           Volvo 240      33.55
# 92           Volvo 850                 850      39.05
#
# [93 rows x 29 columns]

# %%
df2_modif = df1_modif[['Car_Name','Price','Origin']]
df2_modif
# Out:
#               Car_Name  Price   Origin
# 0        Acura Integra   15.9  non-USA
# 1               Legend   33.9  non-USA
# 2              Audi 90   29.1  non-USA
# 3             Audi 100   37.7  non-USA
# 4             BMW 535i   30.0  non-USA
# ..                 ...    ...      ...
# 88  Volkswagen Eurovan   19.7      NaN
# 89   Volkswagen Passat   20.0  non-USA
# 90  Volkswagen Corrado   23.3  non-USA
# 91           Volvo 240   22.7  non-USA
# 92                 850   26.7  non-USA
#
# [93 rows x 3 columns]

# %%
df2_modif[df2_modif.isnull().any(axis=1)]
# Out:
#               Car_Name  Price Origin
# 18  Chevrolet Corvette   38.0    NaN
# 46      Hyundai Sonata   13.9    NaN
# 57  Mercedes-Benz 190E   31.9    NaN
# 71      Plymouth Laser   14.4    NaN
# 88  Volkswagen Eurovan   19.7    NaN

# %% [markdown]
# Sekarang null yang dimiliki adalah 5% dari data, oleh karena itu akan dilakukan delete row.

# %%
df2_drop = df2_modif.copy()
df2_drop.dropna(axis=0,inplace=True)
df2_drop
# Out:
#               Car_Name  Price   Origin
# 0        Acura Integra   15.9  non-USA
# 1               Legend   33.9  non-USA
# 2              Audi 90   29.1  non-USA
# 3             Audi 100   37.7  non-USA
# 4             BMW 535i   30.0  non-USA
# ..                 ...    ...      ...
# 87      Volkswagen Fox    9.1  non-USA
# 89   Volkswagen Passat   20.0  non-USA
# 90  Volkswagen Corrado   23.3  non-USA
# 91           Volvo 240   22.7  non-USA
# 92                 850   26.7  non-USA
#
# [88 rows x 3 columns]

# %%
#Dilakukan penamaan baru untuk mempermudah melihat step
df3 = df2_drop.copy()
df3['Origin'].value_counts()
# Out:
# USA        46
# non-USA    42
# Name: Origin, dtype: int64

# %% [markdown]
# Setelah di lakukan cleaning null values, di cek apakah terdapat value yang typo.
#
# Hasilnya, pada kolom Origin tidak terdapat value yg typo.
#
# Langkah selanjutnya akan dilihat apakah terdapat data yang duplicate/double.

# %%
df3[df3['Car_Name'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Car_Name, Price, Origin]
# Index: []

# %% [markdown]
# Untuk kolom yang di cek adalah kolom Car_Name dan hasilnya tidak terdapat data yang duplicate/double.
#
# Selanjutnya, akan di lihat apakah terdapat outlier pada masing-masing origin.

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88 entries, 0 to 92
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Car_Name  88 non-null     object
#  1   Price     88 non-null     float64
#  2   Origin    88 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 2.8+ KB

# %%
df3_usa = df3[df3['Origin']=='USA']
df3_usa
# Out:
#                     Car_Name  Price Origin
# 5              Buick Century  15.70    USA
# 6              Buick LeSabre  20.80    USA
# 7           Buick Roadmaster  23.70    USA
# 8              Buick Riviera  26.30    USA
# 9           Cadillac DeVille  34.70    USA
# 10          Cadillac Seville  40.10    USA
# 11        Chevrolet Cavalier  13.40    USA
# 12         Chevrolet Corsica  11.40    USA
# 13          Chevrolet Camaro  15.10    USA
# 14          Chevrolet Lumina  15.90    USA
# 15      Chevrolet Lumina_APV  16.30    USA
# 16           Chevrolet Astro  16.60    USA
# 17         Chevrolet Caprice  18.80    USA
# 19                  Concorde  18.40    USA
# 20          Chrysler LeBaron  15.80    USA
# 21         Chrysler Imperial  29.50    USA
# 22                Dodge Colt   9.20    USA
# 23              Dodge Shadow  11.30    USA
# 24              Dodge Spirit  13.30    USA
# 25             Dodge Caravan  19.00    USA
# 26             Dodge Dynasty  15.60    USA
# 27             Dodge Stealth  25.80    USA
# 28              Eagle Summit  12.20    USA
# 29              Eagle Vision  19.30    USA
# 30              Ford Festiva   7.40    USA
# 31               Ford Escort  10.10    USA
# 32                Ford Tempo  11.30    USA
# 33              Ford Mustang  15.90    USA
# 34                Ford Probe  14.00    USA
# 35             Ford Aerostar  19.90    USA
# 36               Ford Taurus  20.20    USA
# 37       Ford Crown_Victoria  20.90    USA
# 50       Lincoln Continental  34.30    USA
# 51          Lincoln Town_Car  36.10    USA
# 59                  Mercury   14.10    USA
# 60            Mercury Cougar  14.90    USA
# 67        Oldsmobile Achieva  13.50    USA
# 68  Oldsmobile Cutlass_Ciera  16.30    USA
# 69     Oldsmobile Silhouette  19.50    USA
# 70   Oldsmobile Eighty-Eight  20.70    USA
# 72            Pontiac LeMans   9.00    USA
# 73           Pontiac Sunbird  11.10    USA
# 74          Pontiac Firebird  17.70    USA
# 75        Pontiac Grand_Prix  18.50    USA
# 76        Pontiac Bonneville  24.40    USA
# 78                 Saturn SL  15.65    USA

# %%
df3_nonusa = df3[df3['Origin']=='non-USA']
df3_nonusa
# Out:
#                Car_Name  Price   Origin
# 0         Acura Integra   15.9  non-USA
# 1                Legend   33.9  non-USA
# 2               Audi 90   29.1  non-USA
# 3              Audi 100   37.7  non-USA
# 4              BMW 535i   30.0  non-USA
# 38            Geo Metro    8.4  non-USA
# 39            Geo Storm   12.5  non-USA
# 40        Honda Prelude   19.8  non-USA
# 41          Honda Civic   12.1  non-USA
# 42         Honda Accord   17.5  non-USA
# 43        Hyundai Excel    8.0  non-USA
# 44      Hyundai Elantra   10.0  non-USA
# 45       Hyundai Scoupe   10.0  non-USA
# 47         Infiniti Q45   47.9  non-USA
# 48          Lexus ES300   28.0  non-USA
# 49                SC300   35.2  non-USA
# 52            Mazda 323    8.3  non-USA
# 53        Mazda Protege   11.6  non-USA
# 54            Mazda 626   16.5  non-USA
# 55            Mazda MPV   19.1  non-USA
# 56           Mazda RX-7   32.5  non-USA
# 58   Mercedes-Benz 300E   61.9  non-USA
# 61    Mitsubishi Mirage   10.3  non-USA
# 62  Mitsubishi Diamante   26.1  non-USA
# 63        Nissan Sentra   11.8  non-USA
# 64        Nissan Altima   15.7  non-USA
# 65         Nissan Quest   19.1  non-USA
# 66        Nissan Maxima   21.5  non-USA
# 77             Saab 900   28.7  non-USA
# 79         Subaru Justy    8.4  non-USA
# 80        Subaru Loyale   10.9  non-USA
# 81        Subaru Legacy   19.5  non-USA
# 82         Suzuki Swift    8.6  non-USA
# 83        Toyota Tercel    9.8  non-USA
# 84        Toyota Celica   18.4  non-USA
# 85         Toyota Camry   25.8  non-USA
# 86        Toyota Previa   22.7  non-USA
# 87       Volkswagen Fox    9.1  non-USA
# 89    Volkswagen Passat   20.0  non-USA
# 90   Volkswagen Corrado   23.3  non-USA
# 91            Volvo 240   22.7  non-USA
# 92                  850   26.7  non-USA

# %%
df3_usa.boxplot(column=['Price'],fontsize=10,rot=0,grid=False,figsize=(10,10),vert=False)

# %%
df3_nonusa.boxplot(column=['Price'],fontsize=10,rot=0,grid=False,figsize=(10,10),vert=False)

# %% [markdown]
# Pada boxplot tsb, terlihat bahwa baik pada kategori USA dan non-USA terdapat indikasi adanya outlier.

# %%
#usa
Q1_usa = df3_usa['Price'].quantile(0.25)
Q3_usa = df3_usa['Price'].quantile(0.75)
#non-usa
Q1_nonusa = df3_nonusa['Price'].quantile(0.25)
Q3_nonusa = df3_nonusa['Price'].quantile(0.75)

def box_min (q1,q3) :
  IQR = q3 - q1
  min = q1 - 1.5 * IQR
  return (min)

def box_max (q1,q3) :
  IQR = q3 - q1
  max = q3 + 1.5 * IQR
  return (max)

# %%
#usa
df3_usa_filtermin = df3_usa['Price'] < box_min(Q1_usa,Q3_usa)
df3_usa_filtermax = df3_usa['Price'] > box_max(Q1_usa,Q3_usa)
#non-usa
df3_nonusa_filtermin = df3_nonusa['Price'] < box_min(Q1_nonusa,Q3_nonusa)
df3_nonusa_filtermax = df3_nonusa['Price'] > box_max(Q1_nonusa,Q3_nonusa)

# %%
df3_usa_clean = df3_usa[~(df3_usa_filtermin|df3_usa_filtermax)]
df3_usa_clean
# Out:
#                     Car_Name  Price Origin
# 5              Buick Century  15.70    USA
# 6              Buick LeSabre  20.80    USA
# 7           Buick Roadmaster  23.70    USA
# 8              Buick Riviera  26.30    USA
# 11        Chevrolet Cavalier  13.40    USA
# 12         Chevrolet Corsica  11.40    USA
# 13          Chevrolet Camaro  15.10    USA
# 14          Chevrolet Lumina  15.90    USA
# 15      Chevrolet Lumina_APV  16.30    USA
# 16           Chevrolet Astro  16.60    USA
# 17         Chevrolet Caprice  18.80    USA
# 19                  Concorde  18.40    USA
# 20          Chrysler LeBaron  15.80    USA
# 21         Chrysler Imperial  29.50    USA
# 22                Dodge Colt   9.20    USA
# 23              Dodge Shadow  11.30    USA
# 24              Dodge Spirit  13.30    USA
# 25             Dodge Caravan  19.00    USA
# 26             Dodge Dynasty  15.60    USA
# 27             Dodge Stealth  25.80    USA
# 28              Eagle Summit  12.20    USA
# 29              Eagle Vision  19.30    USA
# 30              Ford Festiva   7.40    USA
# 31               Ford Escort  10.10    USA
# 32                Ford Tempo  11.30    USA
# 33              Ford Mustang  15.90    USA
# 34                Ford Probe  14.00    USA
# 35             Ford Aerostar  19.90    USA
# 36               Ford Taurus  20.20    USA
# 37       Ford Crown_Victoria  20.90    USA
# 59                  Mercury   14.10    USA
# 60            Mercury Cougar  14.90    USA
# 67        Oldsmobile Achieva  13.50    USA
# 68  Oldsmobile Cutlass_Ciera  16.30    USA
# 69     Oldsmobile Silhouette  19.50    USA
# 70   Oldsmobile Eighty-Eight  20.70    USA
# 72            Pontiac LeMans   9.00    USA
# 73           Pontiac Sunbird  11.10    USA
# 74          Pontiac Firebird  17.70    USA
# 75        Pontiac Grand_Prix  18.50    USA
# 76        Pontiac Bonneville  24.40    USA
# 78                 Saturn SL  15.65    USA

# %%
df3_nonusa_clean = df3_nonusa[~(df3_nonusa_filtermin|df3_nonusa_filtermax)]
df3_nonusa_clean
# Out:
#                Car_Name  Price   Origin
# 0         Acura Integra   15.9  non-USA
# 1                Legend   33.9  non-USA
# 2               Audi 90   29.1  non-USA
# 3              Audi 100   37.7  non-USA
# 4              BMW 535i   30.0  non-USA
# 38            Geo Metro    8.4  non-USA
# 39            Geo Storm   12.5  non-USA
# 40        Honda Prelude   19.8  non-USA
# 41          Honda Civic   12.1  non-USA
# 42         Honda Accord   17.5  non-USA
# 43        Hyundai Excel    8.0  non-USA
# 44      Hyundai Elantra   10.0  non-USA
# 45       Hyundai Scoupe   10.0  non-USA
# 47         Infiniti Q45   47.9  non-USA
# 48          Lexus ES300   28.0  non-USA
# 49                SC300   35.2  non-USA
# 52            Mazda 323    8.3  non-USA
# 53        Mazda Protege   11.6  non-USA
# 54            Mazda 626   16.5  non-USA
# 55            Mazda MPV   19.1  non-USA
# 56           Mazda RX-7   32.5  non-USA
# 61    Mitsubishi Mirage   10.3  non-USA
# 62  Mitsubishi Diamante   26.1  non-USA
# 63        Nissan Sentra   11.8  non-USA
# 64        Nissan Altima   15.7  non-USA
# 65         Nissan Quest   19.1  non-USA
# 66        Nissan Maxima   21.5  non-USA
# 77             Saab 900   28.7  non-USA
# 79         Subaru Justy    8.4  non-USA
# 80        Subaru Loyale   10.9  non-USA
# 81        Subaru Legacy   19.5  non-USA
# 82         Suzuki Swift    8.6  non-USA
# 83        Toyota Tercel    9.8  non-USA
# 84        Toyota Celica   18.4  non-USA
# 85         Toyota Camry   25.8  non-USA
# 86        Toyota Previa   22.7  non-USA
# 87       Volkswagen Fox    9.1  non-USA
# 89    Volkswagen Passat   20.0  non-USA
# 90   Volkswagen Corrado   23.3  non-USA
# 91            Volvo 240   22.7  non-USA
# 92                  850   26.7  non-USA

# %% [markdown]
# Setelah didapatkan data yang sudah clean, akan di gabungkan menjadi 1 dataframe kembali.
#
# Data sudah dapat digunakan untuk Analisis lebih lanjut.

# %%
df4 = pd.concat ([df3_usa_clean,df3_nonusa_clean],axis=0)
df4
# Out:
#               Car_Name  Price   Origin
# 5        Buick Century   15.7      USA
# 6        Buick LeSabre   20.8      USA
# 7     Buick Roadmaster   23.7      USA
# 8        Buick Riviera   26.3      USA
# 11  Chevrolet Cavalier   13.4      USA
# ..                 ...    ...      ...
# 87      Volkswagen Fox    9.1  non-USA
# 89   Volkswagen Passat   20.0  non-USA
# 90  Volkswagen Corrado   23.3  non-USA
# 91           Volvo 240   22.7  non-USA
# 92                 850   26.7  non-USA
#
# [83 rows x 3 columns]
